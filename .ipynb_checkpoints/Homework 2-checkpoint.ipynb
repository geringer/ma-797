# %% [markdown]
# # Homework 2
# ### Adam Geringer
#
# Here are our helper functions

# %%
def plot(w, inputs):
    if w != None:
        x = np.linspace(0, 2, 2).reshape((2, 1))

        slope = - (weights[0] / weights[2]) / (weights[0] / weights[1])  
        intercept = -weights[0] / weights[2]

        y = slope * x + intercept

        print("y = ", slope , "x + ", intercept)
        plt.plot(x , y, '-r')

    for point in inputs:

        if inputs[point] == 1:
            color = 'blue'
            marker = 'o'
        else:
            color = 'red'
            marker = "x"

        plt.scatter(point[0], point[1], color = color ,marker = marker)
    plt.show()

def calc_error(inputs, weights):
    total = 0.0
    num_wrong = 0.0
    
    for point in inputs:
        y_hat = predict(point, weights)
        
        if y_hat != inputs[point]:
            num_wrong += 1.0
            total +=1.0
        else:
            total +=1.0

    return num_wrong / total

def predict(X, weights):
    f = np.dot(weights[1:], X) + weights[0]

    if f > 0:
        activation = 1
    else:

        activation = -1
        
    return activation

def get_error(y_hat, y):
    
    if len(y_hat) != len(y):
        raise "Vector size mismatch"

def PLA(weights, inputs, iterations, learning_rate = .1, plot_me = True):   
    for epoch in range(iterations):
        
        if  epoch % 5 == 0 and plot_me:
#             print("Weights for epoch ", epoch, " = ",weights)
            plot(weights, inputs)
        
        for X in inputs:
            
            y = inputs[X]
            
            activation = predict(X, weights)
            
            update = learning_rate * (y - activation)
            
            for i in range(len(X)):
                weights[i + 1] += update * X[i]

            weights[0] += update
            
    return weights

# %% [markdown]
# # Problem 1
#
# This is a simple data set to illustrate the Perceptron Learning Model. Consider the following
# training data with two categories (labels):
#
# #### C1(1) :
# (0, 1.5)T
# (1, 1)T
# (2, 2)T
# (2, 0)T
#
# #### C2(−1) :
# (0, 0)T
# (1, 0)T
# (0, 1)T
#
# That is, there are seven training data points, each data point has two features and a corre-
# sponding label.
#
# ### (a) Plot these seven training data points and observe that they are separable.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

C1 = np.array([ [0, 1.5], [1, 1], [2, 2], [2, 0] ])
C2 = np.array([ [0, 0], [1, 0], [0, 1] ])

inputs = {}
for point in C1[:,]:
    inputs[(point[0], point[1])] = 1
for point in C2[:,]:
    inputs[(point[0], point[1])] = -1
    
plot(None, inputs)

# %% [markdown]
# ### (b) Starting with the weights
#
# w = (−2, 4, 1)T, where w0 = −2 is the threshold with corresponding artificial coordinate x0 = 1.
#
# Plot the linear model wT x = 0. Note that, this linear model doesn’t separate all data points.

# %%
weights = [-2.0, 4.0, 1.0]
plot(weights, inputs)
# Out:
# y =  -4.0 x +  2.0

# %% [markdown]
# ### (c) Using the Perceptron Learning Algorithm,
# update the weights so that the linear model will eventually separate all seven data points. At each iteration, plot the linear model on the same plot with the data points.
#
# Please show all performed calculations at each iteration of the perceptron learning algorithm
# as well as the plots.

# %%
weights = [-2.0, 4.0, 1.0] 

PLA(weights, inputs, 1000)
# Out:
# y =  -4.0 x +  2.0
# y =  -1.57894736842 x +  1.26315789474
# y =  -1.36842105263 x +  1.47368421053
# y =  -1.36842105263 x +  1.47368421053
# y =  -1.36842105263 x +  1.47368421053
# y =  -1.36842105263 x +  1.47368421053
# y =  -1.36842105263 x +  1.47368421053
# y =  -1.36842105263 x +  1.47368421053
# y =  -1.36842105263 x +  1.47368421053
# y =  -1.36842105263 x +  1.47368421053
# y =  -1.36842105263 x +  1.47368421053
# y =  -1.36842105263 x +  1.47368421053
# y =  -1.36842105263 x +  1.47368421053
# y =  -1.36842105263 x +  1.47368421053
# y =  -1.36842105263 x +  1.47368421053
# y =  -1.36842105263 x +  1.47368421053
# y =  -1.36842105263 x +  1.47368421053
# y =  -1.36842105263 x +  1.47368421053
# y =  -1.36842105263 x +  1.47368421053
# y =  -1.36842105263 x +  1.47368421053
# y =  -1.36842105263 x +  1.47368421053
# y =  -1.36842105263 x +  1.47368421053
# y =  -1.36842105263 x +  1.47368421053
# y =  -1.36842105263 x +  1.47368421053
# ...

# %% [markdown]
# # Problem 2
# The MATLAB file, SampleCredit.mat, is the data set for the credit card applications. The pdf
# file, CreditApproval.pdf, has a description for this data set. It is noted the values in the data
# set was changed by the authors to protect the confidentiality of the data. Use the first 500
# data for the training set and the rest for the testing set. Write your own code to implement
# the Perceptron Learning Algorithm for this data set. For the hyperparameters, set the learning
# rate to be 0.1 and the number of epochs to be 1000. For the output, report the accuracy for
# the training data as well as the testing data for the following two cases:
#
# ### (a) Data is used unchanged.

# %%
import scipy.io as sio

mat = sio.loadmat("bin/SampleCredit.mat")
train_inputs = {}
test_inputs = {}

for i in range(len(mat['label'])):
    if i < 500:
        train_inputs[tuple(mat['sample'][i])] = int(mat['label'][i][0])
    else:
        test_inputs[tuple(mat['sample'][i])] = int(mat['label'][i][0])

weights = list(np.random.randn(16))
weights = PLA(weights, train_inputs, 1000, .1, plot_me = False)
print(calc_error(test_inputs, weights))
# Out:
# 0.3202614379084967

# %% [markdown]
# ### (b) Data is normalized by the maximum value of each feature.

# %%
from sklearn.preprocessing import normalize

A = np.vstack(mat['sample'])
    
A = normalize(A, axis = 0, norm='max')

train_inputs = {}
test_inputs = {}

for i in range(len(mat['label'])):
    if i < 500:
        train_inputs[tuple(A[i])] = int(mat['label'][i][0])
    else:
        test_inputs[tuple(A[i])] = int(mat['label'][i][0])

weights = list(np.random.randn(16))
weights = PLA(weights, train_inputs, 1000, .1, plot_me = False)
print(calc_error(test_inputs, weights))
# Out:
# 0.16993464052287582
